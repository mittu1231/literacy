# %% [markdown]
# <a href="https://colab.research.google.com/github/mittu1231/literacy/blob/main/chapters/08_cipher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [矢吹太朗『Webのしくみ』（サイエンス社, 2020）](https://github.com/taroyabuki/webbook)
#
# 下のアイコンをクリックすれば，この文書に掲載されているコードを，Google Colab上で実行できます．（Googleのアカウントが必要です．）
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/taroyabuki/webbook/blob/master/chapters/08_cipher.ipynb)
#
# # 第8章 暗号

# %% [markdown]
# ## 8.1 事後否認・改ざん・なりすまし・盗聴

# %% [markdown]
# ## 8.2 暗号の基本
#
# ![図8.1 シーザー暗号（「+13」文字ずらす）を使って，アリスがボブにメッセージを送っている様子](https://raw.githubusercontent.com/taroyabuki/webbook/master/chapters/figures/08-1.svg)

# %%
#準備
# !apt-get install -y -qq hxtools > /dev/null

# %%
#暗号化
# !echo "hello" | rot13

# %%
#復号
# !echo "hello" | rot13 | rot13

# %% [markdown]
# ## 8.3 公開鍵暗号

# %% [markdown]
# ### 8.3.1 盗聴への対策
#
# アリスはボブの公開鍵で暗号化し，ボブはボブの秘密鍵で復号します．
#
# ![図8.2 公開鍵暗号を使った暗号化と復号](https://raw.githubusercontent.com/taroyabuki/webbook/master/chapters/figures/08-2.svg)
#
# ファイル|役割
# --|--
# bob-public.pem|ボブの公開鍵
# bob-private.pem|ボブの秘密鍵
# message4bob|ボブへのメッセージ
# message4bob-secret|ボブへの暗号文

# %%
#(1) ボブが公開鍵と矢吹秘密鍵を作る．
# !openssl genrsa -out yabuki-private.pem.txt 2048
# !openssl rsa -in yabuki-private.pem.txt -pubout -out bob-public.pem
# Out:
# writing RSA key

# %%
#公開鍵を見てみる．
# !cat bob-public.pem
# Out:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEAy6schWZ1RgnZzaaJnDRu
# NpEgD3fM7ZVP5lHB1PLRxlkmxAjQvJtx+LpCFGNgrlr99zHQw87FwMZy4rZ87kYE
# NIQ2xglyq/4WzJ3WdUdgfW6jFD0ddTKHxPsUpULbNu5sbFQ/BcmPen+y3EU94Y8/
# vDWIVdzSSR5At+Rw/Gd1cbTmjHs1l4dInOZkikJuLB7mLrYIepFN6tVYFnh913qq
# NgACbVae1dAnsz5pykj+PwJTeUHH2jp9YGNVYQSnaOqE3r8GtB/WWd6eAXNbg3Kc
# RhR2dVArB7CUDRcOYqlQgLC4OEFGn8aRkwpXrJNYYNOTsidus3+q2sQYq2OuOZck
# EwIDAQAB
# -----END PUBLIC KEY-----

# %%
#秘密鍵を見てみる（秘密鍵は本来見せたり公開したりしてはいけない）．
# !cat yabuki-private.pem.txt
# Out:
# -----BEGIN PRIVATE KEY-----
# MIIEvQIBADANBgkqhkiG9w0BAQEFAASCBKcwggSjAgEAAoIBAQDLqxyFZnVGCdnN
# pomcNG42kSAPd8ztlU/mUcHU8tHGWSbECNC8m3H4ukIUY2CuWv33MdDDzsXAxnLi
# vg3lpdM3yfe4dLBlGUdLNeTA91Gp8E+bAcC2R0Ucp9rWEOK+zygAQujiZ58eZtKX
# UakP5krd9Br16mgEE8mCSO/x2Fmj0YVv+WsuS19d385rCv35hei85cWKLHzbNyDQ
# Vh+fytm2Nggheek/n/ykWMA=
# -----END PRIVATE KEY-----

# %%
#(2) ボブが公開鍵を公開する．

#(3) アリスがボブの公開鍵を手に入れる．

#(4) アリスがボブの公開鍵を使ってメッセージを暗号化し，ボブに送る．

#(4.1) メッセージをファイルに書く．
# !printf "26G3087" > report

#(4.2) ボブの公開鍵を使って暗号文を作る．
# !openssl pkeyutl -encrypt -pubin -inkey bob-public.pem -in report -out report-secret
# !base64 report-secret
# Out:
# tieQtjHHDgJCGTnoPkuhhR044xoY9s8Z0dx7MyWEmrB3X04UtNnlWoMRtwfxv+gIynwKGHqaurWh
# UTsRh3GRG8B5z6IFYlRyiXeHpP9fi4tFyGTGVf/cd2jYIV6FARlF/jlIGsho/2wmI68aZpkopFtA
# 2kf50MPWv6lZClpYm1D/T74avrA4/6aDBrSVhO/p/kPLlG05UirHEVlReeNlIg4mctqEDz07z1gz
# ZgSrfLseesb2nJvKMr4fvswxGmQyECscoMmR7D5onR7RA2vnI0jgwE9tDlC7h+y9stZxURrJjNDg
# p3pZjaYOC7t8Qr2JSghopu8C5qjrf93h8cFCwQ==

# %%
#(5) ボブが暗号文を受け取り，秘密鍵を使って復号する．
# !openssl pkeyutl -decrypt -inkey yabuki-private.pem.txt -in report-secret
# Out:
# 26G3087

# %% [markdown]
# ### 8.3.2 デジタル署名
#
# アリスはアリスの秘密鍵でデジタル署名を作り，ボブはアリスの公開鍵でデジタル署名を検証します．
#
# ファイル|役割
# --|--
# alice-public.pem|アリスの公開鍵
# alice-private.pem|アリスの秘密鍵
# alice-message|アリスのメッセージ
# alice-message-signature|アリスのデジタル署名

# %% [markdown]
# #### デジタル署名

# %%
#(1) アリスが公開鍵と秘密鍵を作る．
# !openssl genrsa -out alice-private.pem 2048
# !openssl rsa -in alice-private.pem -pubout -out alice-public.pem

# %%
#(2) アリスがメッセージをファイルに書き，アリスが秘密鍵を使ってデジタル署名を作る．
# !printf "HELLO\n" > alice-message
# !openssl dgst -sha256 -sign alice-private.pem -out alice-message-signature alice-message

# %%
#(3) アリスが公開鍵を公開する．

#(4) ボブがアリスの公開鍵，メッセージ，デジタル署名を取得する．

#(5) ボブがアリスの公開鍵を使って，メッセージのデジタル署名を検証する．
# !openssl dgst -sha256 -verify alice-public.pem -signature alice-message-signature alice-message

# %% [markdown]
# ### 8.3.3 デジタル証明書

# %% [markdown]
# ## 8.4 ウェブの安全性

# %% [markdown]
# ### 8.4.1 TLS
